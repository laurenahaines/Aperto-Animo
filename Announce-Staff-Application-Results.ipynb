# %%
import pandas as pd
import smtplib

''' Assign the following STRING variables.

    Assign  <your_name> to your first name, space, last name (e.g., Lauren Haines)
  
    Assign <your_email> and <your_password> to your Gmail credentials
    
        If you use 2-factor authentification, set <your_password> to an 'app password':
        https://support.google.com/accounts/answer/185833?hl=en 
    
    Assign <contacts> to a locally stored Excel spreadsheet with these column labels:
    
            Name
            Email
            Role
            
    Assign <publication_year> to the publication year for which you are recruiting (e.g., 2023-24) 
    Assign <scheduling_link> to a scheduling survey (e.g., the link to a When2Meet event)
    Assign <disclosure_link> to a personal disclosure survey (e.g., the link to a Google Form)
    Assign <deadline> to a final date for recipients to fill out the scheduling and personal disclosure surveys. (e.g., March 20th)
    Assign <note> to a personal note to follow the heading 'About Me:' (e.g., I'm blah blah blah)


Good luck! '''

# We set your personal information
your_name = 

# We set your Gmail credentials
your_email = 
your_password = 

# We set the path to the contact spreadsheet
contacts =

# We set additional informationn
publication_year = 
scheduling_link = 
disclosure_link = 
deadline = 

# We set your personal note
note =

# %%
''' Don't change these lines. '''

''' Run the cell ONCE. Running multiple times will send duplicate emails.'''

# We enter your Gmail account
server = smtplib.SMTP_SSL('smtp.gmail.com', 465)
server.ehlo()
server.login(your_email, your_password)

# We read the <contacts> spreadsheet
email_list = pd.read_excel(contacts)
all_names = email_list['Name']
all_emails = email_list['Email']
all_roles = email_list['Role']

# We send the recruitment email to each contact in <contacts>
for idx in range(len(all_emails)):

    name = all_names[idx]
    email = all_emails[idx]
    role = all_roles[idx]

    full_email = (
        
        "From: {0} <{1}>\n"
        "To: <{2}>\n"
        "Subject: Welcome to Aperto Animo! \n\n"  
       
         "Dear {3},\n\n"
        
        "Congratulations! As the {5} Editor-in-Chief, it's my pleasure to welcome you aboard the {5} Aperto Animo {4}.\n\n"
        
        "I'm confident that you will accomplish great things on the merit of your qualifications, experience, and personal testimony."
        " You'll soon have the opportunity to meet your collegues, learn more about the history of Aperto Animo, and recieve additional context for the responsibilties that come with your role."
        " Before then, I have two immediate action items for you to complete ASAP."
        " They should take less than 5 minutes from start to finish. \n\n"

        "Note that if I haven't heard from you by {8}, I will assume that you have declined to accept your role. \n\n"
        
        "First, please fill out this personal disclosure survey: {7} \n\n"
        
        "Second, fill out this scheduling survey: {6} \n\n"
        
        "That's all! I look forward to meeting you in person. \n\n"
        
        "{0} \n\n"
        
        "About me: {9} \n\n"
        
        # {0} your name, {1} your email,
        # {2} their email, {3} their name, {4} their role
        # {5} publication year, {6} scheduling link, {7} disclosures link, {8} deadline
        # {9} note
        .format(your_name, your_email, email, name, role, publication_year, scheduling_link, disclosure_link, deadline, note))

    try:
        server.sendmail(your_email, [email], full_email)
        print('Email to {} successfully sent!\n\n'.format(email))
    except Exception as e:
        print('Email to {} could not be sent :( because {}\n\n'.format(email, str(e)))

# We exit your Gmail account
server.close()
# Out:
# Email to lahaines@email.unc.edu successfully sent!
#
#
# Email to igbryant@email.unc.edu successfully sent!
#
#
# Email to ivelynha@unc.edu successfully sent!
#
#
# Email to smartin4@email.unc.edu successfully sent!
#
#
# Email to robclay@unc.edu successfully sent!
#
#
# Email to ajain@unc.edu successfully sent!
#
#
# Email to nbelcher@unc.edu successfully sent!
#
#
# Email to tricketts@unc.edu successfully sent!
#
#
# Email to acarmack@email.unc.edu successfully sent!
#
#
# Email to jmacejka@ad.unc.edu successfully sent!
#
#
# Email to brookealester@gmail.com successfully sent!
#
#
# Email to clwarr@unc.edu successfully sent!
#
#
# Email to eparis@unc.edu successfully sent!
#
#
# Email to jprause@unc.edu successfully sent!
#
#
# Email to nattrav@ad.unc.edu successfully sent!
#
#
# Email to anngoul@email.unc.edu successfully sent!
#
#
# Email to coreycd@ad.unc.edu successfully sent!
# ---------------------------------------------------------------------------
# ...
